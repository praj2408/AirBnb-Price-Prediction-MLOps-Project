# %% [markdown]
# # Importing the libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Read the dataset

# %%
df = pd.read_csv("data/Airbnb_Data.csv")

# %%
df.head()
# Out:
#          id  log_price property_type        room_type  \
# 0   6901257   5.010635     Apartment  Entire home/apt
# 1   6304928   5.129899     Apartment  Entire home/apt
# 2   7919400   4.976734     Apartment  Entire home/apt
# 3  13418779   6.620073         House  Entire home/apt
# 4   3808709   4.744932     Apartment  Entire home/apt
#
#                                            amenities  accommodates  bathrooms  \
# 0  {"Wireless Internet","Air conditioning",Kitche...             3        1.0
# 1  {"Wireless Internet","Air conditioning",Kitche...             7        1.0
# 2  {TV,"Cable TV","Wireless Internet","Air condit...             5        1.0
# 3  {TV,"Cable TV",Internet,"Wireless Internet",Ki...             4        1.0
# 4  {TV,Internet,"Wireless Internet","Air conditio...             2        1.0
#
#    bed_type cancellation_policy  cleaning_fee  ...   latitude   longitude  \
# 0  Real Bed              strict          True  ...  40.696524  -73.991617
# ...

# %%
df.tail()
# Out:
#              id  log_price property_type        room_type  \
# 74106  14549287   4.605170     Apartment     Private room
# 74107  13281809   5.043425     Apartment  Entire home/apt
# 74108  18688039   5.220356     Apartment  Entire home/apt
# 74109  17045948   5.273000     Apartment  Entire home/apt
# 74110   3534845   4.852030          Boat  Entire home/apt
#
#                                                amenities  accommodates  \
# 74106                                                 {}             1
# 74107  {TV,"Cable TV",Internet,"Wireless Internet",Ki...             4
# 74108  {TV,Internet,"Wireless Internet","Air conditio...             5
# 74109  {TV,"Wireless Internet","Air conditioning",Kit...             2
# 74110  {TV,Internet,"Wireless Internet",Kitchen,"Free...             4
#
#        bathrooms  bed_type cancellation_policy  cleaning_fee  ...   latitude  \
# 74106        1.0  Real Bed            flexible         False  ...  40.709025
# ...

# %%
df.shape
# Out:
# (74111, 29)

# %% [markdown]
# **So there are 74111 observations and 29 features**

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **There are no duplicates in this dataset**

# %%
df.isnull().sum()
# Out:
# id                            0
# log_price                     0
# property_type                 0
# room_type                     0
# amenities                     0
# accommodates                  0
# bathrooms                   200
# bed_type                      0
# cancellation_policy           0
# cleaning_fee                  0
# city                          0
# description                   0
# first_review              15864
# host_has_profile_pic        188
# host_identity_verified      188
# host_response_rate        18299
# host_since                  188
# instant_bookable              0
# last_review               15827
# latitude                      0
# longitude                     0
# name                          0
# neighbourhood              6872
# number_of_reviews             0
# review_scores_rating      16722
# thumbnail_url              8216
# zipcode                     966
# bedrooms                     91
# beds                        131
# ...

# %%
import missingno as msno
# %matplotlib inline

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
msno.bar(df)
# Out:
# <Axes: >

# %% [markdown]
# - first_review, host_response_rate, last_review and review_scores_rating has around 20% of missing values

# %%
msno.heatmap(df,labels=True)
# Out:
# <Axes: >

# %%
msno.dendrogram(df)
# Out:
# <Axes: >

# %% [markdown]
# - **There are two groups distinguished: the left group boasts fully developed features without any null values, while the first group is nearly complete but contains a few minor null values. In contrast, the right group exhibits a higher prevalence of missing values**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74111 entries, 0 to 74110
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      74111 non-null  int64
#  1   log_price               74111 non-null  float64
#  2   property_type           74111 non-null  object
#  3   room_type               74111 non-null  object
#  4   amenities               74111 non-null  object
#  5   accommodates            74111 non-null  int64
#  6   bathrooms               73911 non-null  float64
#  7   bed_type                74111 non-null  object
#  8   cancellation_policy     74111 non-null  object
#  9   cleaning_fee            74111 non-null  bool
#  10  city                    74111 non-null  object
#  11  description             74111 non-null  object
#  12  first_review            58247 non-null  object
#  13  host_has_profile_pic    73923 non-null  object
# ...

# %% [markdown]
# **There are 10 numerical columns and 18 categorical columns**

# %%
df.drop('id', axis=1, inplace=True)

# %%
df.head()
# Out:
#    log_price property_type        room_type  \
# 0   5.010635     Apartment  Entire home/apt
# 1   5.129899     Apartment  Entire home/apt
# 2   4.976734     Apartment  Entire home/apt
# 3   6.620073         House  Entire home/apt
# 4   4.744932     Apartment  Entire home/apt
#
#                                            amenities  accommodates  bathrooms  \
# 0  {"Wireless Internet","Air conditioning",Kitche...             3        1.0
# 1  {"Wireless Internet","Air conditioning",Kitche...             7        1.0
# 2  {TV,"Cable TV","Wireless Internet","Air condit...             5        1.0
# 3  {TV,"Cable TV",Internet,"Wireless Internet",Ki...             4        1.0
# 4  {TV,Internet,"Wireless Internet","Air conditio...             2        1.0
#
#    bed_type cancellation_policy  cleaning_fee city  ...   latitude  \
# 0  Real Bed              strict          True  NYC  ...  40.696524
# 1  Real Bed              strict          True  NYC  ...  40.766115
# ...

# %% [markdown]
# ## View summary statistics of the data

# %%
df.describe().T
# Out:
#                         count       mean        std         min         25%  \
# log_price             74111.0   4.782069   0.717394    0.000000    4.317488
# accommodates          74111.0   3.155146   2.153589    1.000000    2.000000
# bathrooms             73911.0   1.235263   0.582044    0.000000    1.000000
# latitude              74111.0  38.445958   3.080167   33.338905   34.127908
# longitude             74111.0 -92.397525  21.705322 -122.511500 -118.342374
# number_of_reviews     74111.0  20.900568  37.828641    0.000000    1.000000
# review_scores_rating  57389.0  94.067365   7.836556   20.000000   92.000000
# bedrooms              74020.0   1.265793   0.852143    0.000000    1.000000
# beds                  73980.0   1.710868   1.254142    0.000000    1.000000
#
#                             50%         75%         max
# log_price              4.709530    5.220356    7.600402
# accommodates           2.000000    4.000000   16.000000
# ...

# %% [markdown]
# ## Dealing with missing values

# %%
df.bathrooms.isnull().sum()
# Out:
# 200

# %%
df.bathrooms.value_counts()
# Out:
# bathrooms
# 1.0                                                                                                                                                                                                                                      58099
# 2.0                                                                                                                                                                                                                                       7936
# 1.5                                                                                                                                                                                                                                       3801
# 2.5                                                                                                                                                                                                                                       1567
# ...

# %%
sns.displot(df.bathrooms)
# Out:
# C:\Users\prajw\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.bathrooms.fillna(df.bathrooms.mode, inplace=True)

# %%
## beds

# %%
df.beds.value_counts()
# Out:
# beds
# 1.0     45144
# 2.0     16704
# 3.0      6442
# 4.0      3065
# 5.0      1287
# 6.0       661
# 7.0       216
# 8.0       186
# 10.0       88
# 9.0        72
# 16.0       38
# 12.0       29
# 11.0       23
# 13.0       10
# 15.0        6
# 14.0        4
# 0.0         4
# 18.0        1
# Name: count, dtype: int64

# %%
df.beds.isnull().sum()
# Out:
# 131

# %%
sns.displot(df.beds)
# Out:
# C:\Users\prajw\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.beds.fillna(df.beds.mode, inplace=True)

# %%
## firs_review

# %%
df.first_review.isnull().sum()
# Out:
# 15864

# %% [markdown]
# this is a datatime columns, so we will look into this later

# %%
## host has a profile pic

# %%
df.host_has_profile_pic.isnull().sum()
# Out:
# 188

# %%
df.host_has_profile_pic.value_counts()
# Out:
# host_has_profile_pic
# t    73697
# f      414
# Name: count, dtype: int64

# %%
df.host_has_profile_pic.fillna(value='f', inplace=True)

# %%
## host identity verified

# %%
df.host_identity_verified.isnull().sum()
# Out:
# 188

# %%
df.host_identity_verified.value_counts()
# Out:
# host_identity_verified
# t    49748
# f    24175
# Name: count, dtype: int64

# %%
df.host_identity_verified.fillna(value='f', inplace=True)

# %%
## host response rate

# %%
df.host_response_rate.head()
# Out:
# 0     NaN
# 1    100%
# 2    100%
# 3     NaN
# 4    100%
# Name: host_response_rate, dtype: object

# %%
df.host_response_rate.value_counts()
# Out:
# host_response_rate
# 100%    43254
# 90%      2277
# 80%      1113
# 0%        883
# 50%       611
#         ...
# 39%         1
# 15%         1
# 31%         1
# 21%         1
# 6%          1
# Name: count, Length: 80, dtype: int64

# %%
df.host_response_rate.isnull().sum()
# Out:
# 18299

# %%
sns.displot(df.host_response_rate)
# Out:
# C:\Users\prajw\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.host_response_rate.fillna(value=0, inplace=True)

# %%
## host_since

# %%
df.host_since
# Out:
# 0        2012-03-26
# 1        2017-06-19
# 2        2016-10-25
# 3        2015-04-19
# 4        2015-03-01
#             ...
# 74106    2013-03-24
# 74107    2016-05-03
# 74108    2012-01-05
# 74109    2017-09-17
# 74110    2012-11-26
# Name: host_since, Length: 74111, dtype: object

# %% [markdown]
# we will look into datetime columns later

# %%
## last review

# %%
df.last_review
# Out:
# 0        2016-07-18
# 1        2017-09-23
# 2        2017-09-14
# 3               NaN
# 4        2017-01-22
#             ...
# 74106           NaN
# 74107    2017-04-15
# 74108    2017-09-10
# 74109           NaN
# 74110    2017-04-30
# Name: last_review, Length: 74111, dtype: object

# %%
df.first_review
# Out:
# 0        2016-06-18
# 1        2017-08-05
# 2        2017-04-30
# 3               NaN
# 4        2015-05-12
#             ...
# 74106           NaN
# 74107    2016-08-15
# 74108    2015-01-03
# 74109           NaN
# 74110    2013-09-05
# Name: first_review, Length: 74111, dtype: object

# %%
## neighbourhood

# %%
df.neighbourhood
# Out:
# 0        Brooklyn Heights
# 1          Hell's Kitchen
# 2                  Harlem
# 3            Lower Haight
# 4        Columbia Heights
#                ...
# 74106        Williamsburg
# 74107       Hermosa Beach
# 74108        Williamsburg
# 74109        West Village
# 74110          Long Beach
# Name: neighbourhood, Length: 74111, dtype: object

# %%
df.neighbourhood.value_counts()
# Out:
# neighbourhood
# Williamsburg          2862
# Bedford-Stuyvesant    2166
# Bushwick              1601
# Upper West Side       1396
# Mid-Wilshire          1392
#                       ...
# Mill Basin               1
# Mt. Vernon Square        1
# Chevy Chase, MD          1
# Clearing                 1
# Grant City               1
# Name: count, Length: 619, dtype: int64

# %%
## review score ratings

# %%
df.review_scores_rating.isnull().sum()
# Out:
# 16722

# %%
df.review_scores_rating.value_counts()
# Out:
# review_scores_rating
# 100.0    16215
# 98.0      4374
# 97.0      4087
# 96.0      4081
# 95.0      3713
# 93.0      3647
# 90.0      2852
# 99.0      2631
# 94.0      2618
# 80.0      2163
# 92.0      2064
# 91.0      1615
# 89.0      1120
# 87.0      1119
# 88.0      1056
# 85.0       625
# 86.0       512
# 60.0       444
# 84.0       438
# 83.0       403
# 82.0       211
# 70.0       196
# 73.0       157
# 81.0       126
# 75.0       101
# 20.0        97
# 78.0        94
# 40.0        90
# 79.0        83
# 76.0        76
# 77.0        74
# 67.0        66
# 74.0        39
# 72.0        38
# 50.0        30
# 65.0        28
# 68.0        20
# 71.0        14
# 69.0        13
# 63.0        11
# 53.0        10
# 64.0        10
# 47.0         5
# 30.0         4
# 62.0         3
# 66.0         3
# 55.0         3
# 57.0         3
# 27.0         2
# 35.0         1
# 49.0         1
# 58.0         1
# 54.0         1
# 56.0         1
# Name: count, dtype: int64

# %%
sns.displot(df.review_scores_rating)
# Out:
# C:\Users\prajw\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.review_scores_rating.min()
# Out:
# 20.0

# %% [markdown]
# ## Correlation

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True,linewidth=.5)
# Out:
# <Axes: >

# %% [markdown]
# #### Positive Correlation
#  - log_price = accommodates, bedrooms

# %% [markdown]
# ## Exploratory data analysis

# %%
plt.figure(figsize = (10, 8))
sns.distplot(df.log_price)
plt.title("Price Distribution")
# Out:
# C:\Users\prajw\AppData\Local\Temp\ipykernel_12628\1532230489.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.log_price)
# Text(0.5, 1.0, 'Price Distribution')

# %%
def plot_piechart(h):
    sns.set(font_scale=1.5)
    fig = plt.figure(figsize=(5,5))
    ax = fig.add_axes([0,0,1,1])
    ax.axis('equal')
    langs = list(df[h].unique())
    students =list(df[h].value_counts())
    explode = [0.05, 0, 0]
    ax.pie(students, labels = langs,autopct='%1.2f%%', explode=explode)
    
    plt.show()

# %%
plot_piechart("room_type")
